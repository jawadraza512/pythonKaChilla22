# %% [markdown]
# 1. pandas //python data analysis- (running/exceldataframes and handling data)
# 2. numpy -
# 3. matplotlib - (graphs/plots/)
# 4. seaborn - (based on matplotlib and extra functions too)
# 5. plotly - (dashboards/3d plots/ animated plots/interactive plots)
# 6. scipy - (used for stats analysis/ )
# 7. scikit-learn - (machine learning/ prediction)
# 8. streamlit - (dashboards/ in master & phd/ thsis deploying)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly as px
import seaborn as sns

# %%
# plot
sns.set_theme(style="darkgrid")

diamonds=sns.load_dataset("diamonds")
clarity_ranking=["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(x="clarity", y="carat",
              color="b", order=clarity_ranking,
              scale="linear", data=diamonds)
# Out:
# C:\Users\jawad\AppData\Local\Temp\ipykernel_6020\4088004727.py:7: FutureWarning:
#
# The `scale` parameter has been renamed to `width_method` and will be removed in v0.15. Pass `width_method='linear' for the same effect.
#   sns.boxenplot(x="clarity", y="carat",
# <Axes: xlabel='clarity', ylabel='carat'>
